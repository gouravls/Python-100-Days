# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mtp
import seaborn as snm

# %%
sample_data=pd.read_csv(r"A:\LLM\Sample - Superstore.csv", encoding="ISO-8859-1")
sample_data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
sample_data.shape
# Out:
# (9994, 21)

# %%
sample_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sample_data[5:7]
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 5       6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 6       7  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 5  Brosina Hoffman  Consumer  United States  Los Angeles  ...       90032
# 6  Brosina Hoffman  Consumer  United States  Los Angeles  ...       90032
#
#    Region       Product ID         Category Sub-Category  \
# 5    West  FUR-FU-10001487        Furniture  Furnishings
# 6    West  OFF-AR-10002833  Office Supplies          Art
#
#                                         Product Name  Sales  Quantity  \
# 5  Eldon Expressions Wood and Plastic Desk Access...  48.86         7
# 6                                         Newell 322   7.28         4
#
#    Discount   Profit
# 5       0.0  14.1694
# 6       0.0   1.9656
#
# [2 rows x 21 columns]

# %%
#group by using aggregation function

data1=sample_data.groupby('Segment').agg('count')
data1.head()
# Out:
#              Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# Segment
# Consumer       5191      5191        5191       5191       5191         5191
# Corporate      3020      3020        3020       3020       3020         3020
# Home Office    1783      1783        1783       1783       1783         1783
#
#              Customer Name  Country  City  State  Postal Code  Region  \
# Segment
# Consumer              5191     5191  5191   5191         5191    5191
# Corporate             3020     3020  3020   3020         3020    3020
# Home Office           1783     1783  1783   1783         1783    1783
#
#              Product ID  Category  Sub-Category  Product Name  Sales  \
# Segment
# Consumer           5191      5191          5191          5191   5191
# Corporate          3020      3020          3020          3020   3020
# Home Office        1783      1783          1783          1783   1783
#
#              Quantity  Discount  Profit
# Segment
# ...

# %%
#if you want to save your results in csv file then we need to use to_csv function
#make sure to pass this and add csv extension

data1.to_csv("new_analysis.csv")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Gourav Sikka

# %%
sample_data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
sample_data.tail
# Out:
# <bound method NDFrame.tail of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3          4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4          5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sample_data[2:3]
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 2       3  CA-2016-138688  12-06-2016  16-06-2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name  Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62         2
#
#    Discount  Profit
# 2       0.0  6.8714
#
# [1 rows x 21 columns]

# %%
sample_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#if we need only only column then we need to do like this

sample_data["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
#if we need only more columns then we need to do like this

sample_data[["Sales","Category"]]
# Out:
#          Sales         Category
# 0     261.9600        Furniture
# 1     731.9400        Furniture
# 2      14.6200  Office Supplies
# 3     957.5775        Furniture
# 4      22.3680  Office Supplies
# ...        ...              ...
# 9989   25.2480        Furniture
# 9990   91.9600        Furniture
# 9991  258.5760       Technology
# 9992   29.6000  Office Supplies
# 9993  243.1600  Office Supplies
#
# [9994 rows x 2 columns]

# %%
sample_data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#describe for particulat 1 column
sample_data["Sales"].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
#min for one variable
sample_data["Sales"].min()
# Out:
# 0.444

# %%
#max for one variable
sample_data["Sales"].max()
# Out:
# 22638.48

# %%
#I dodnot want maxium value, I want comple row
sample_data["Sales"]==sample_data["Sales"].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Sales, Length: 9994, dtype: bool

# %%
#I do want maxium value, I want comple row
#great code
sample_data[sample_data["Sales"]==sample_data["Sales"].max()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  18-03-2014  23-03-2014  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
#
#      Postal Code  Region       Product ID    Category Sub-Category  \
# 2697       32216   South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
#
#       Discount     Profit
# 2697       0.5 -1811.0784
#
# [1 rows x 21 columns]

# %%
#I do want maxium value, I want comple row
#great code
sample_data['Ship Mode'][sample_data["Sales"]==sample_data["Sales"].max()]
# Out:
# 2697    Standard Class
# Name: Ship Mode, dtype: object

# %%
#how to apply filter in pandas
sample_data[sample_data["Sales"]==258.5760]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 5179    5180  US-2015-120502  13-04-2015  19-04-2015  Standard Class
# 9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
#
#      Customer ID Customer Name    Segment        Country         City  ...  \
# 5179    BT-11395    Bill Tyler  Corporate  United States  Los Angeles  ...
# 9991    DB-13060   Dave Brooks   Consumer  United States   Costa Mesa  ...
#
#      Postal Code  Region       Product ID    Category Sub-Category  \
# 5179       90036    West  TEC-PH-10003645  Technology       Phones
# 9991       92627    West  TEC-PH-10003645  Technology       Phones
#
#                Product Name    Sales  Quantity  Discount   Profit
# 5179  Aastra 57i VoIP phone  258.576         2       0.2  19.3932
# 9991  Aastra 57i VoIP phone  258.576         2       0.2  19.3932
#
# [2 rows x 21 columns]

# %%
sample_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#group by function with max function

group_date_category=sample_data.groupby('Category').max()
group_date_category
# Out:
#                  Row ID        Order ID  Order Date   Ship Date  \
# Category
# Furniture          9991  US-2017-169551  31-12-2015  31-12-2017
# Office Supplies    9994  US-2017-169551  31-12-2016  31-12-2017
# Technology         9992  US-2017-169551  31-12-2016  31-12-2016
#
#                       Ship Mode Customer ID       Customer Name      Segment  \
# Category
# Furniture        Standard Class    ZD-21925  Zuschuss Donatelli  Home Office
# Office Supplies  Standard Class    ZD-21925  Zuschuss Donatelli  Home Office
# Technology       Standard Class    ZD-21925  Zuschuss Donatelli  Home Office
#
#                        Country  City      State  Postal Code Region  \
# Category
# Furniture        United States  York    Wyoming        99301   West
# Office Supplies  United States  Yuma  Wisconsin        99301   West
# Technology       United States  Yuma  Wisconsin        99207   West
#
#                       Product ID Sub-Category  \
# Category
# ...

# %%
group_date_category.head()
# Out:
#                  Row ID        Order ID  Order Date   Ship Date  \
# Category
# Furniture          9991  US-2017-169551  31-12-2015  31-12-2017
# Office Supplies    9994  US-2017-169551  31-12-2016  31-12-2017
# Technology         9992  US-2017-169551  31-12-2016  31-12-2016
#
#                       Ship Mode Customer ID       Customer Name      Segment  \
# Category
# Furniture        Standard Class    ZD-21925  Zuschuss Donatelli  Home Office
# Office Supplies  Standard Class    ZD-21925  Zuschuss Donatelli  Home Office
# Technology       Standard Class    ZD-21925  Zuschuss Donatelli  Home Office
#
#                        Country  City      State  Postal Code Region  \
# Category
# Furniture        United States  York    Wyoming        99301   West
# Office Supplies  United States  Yuma  Wisconsin        99301   West
# Technology       United States  Yuma  Wisconsin        99207   West
#
#                       Product ID Sub-Category  \
# Category
# ...

# %%
#group by function with max function
sample_data.groupby("City").min()
# Out:
#              Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# City
# Aberdeen       9261  CA-2017-167976  11-11-2017  14-11-2017    Second Class
# Abilene        6990  CA-2017-165099  11-12-2017  13-12-2017     First Class
# Akron           201  CA-2014-111360  04-09-2017  09-09-2017     First Class
# Albuquerque    2417  CA-2014-100881  10-10-2014  01-01-2018        Same Day
# Alexandria      921  CA-2014-102988  04-01-2015  09-01-2015    Second Class
# ...             ...             ...         ...         ...             ...
# Woonsocket     3990  CA-2014-122588  12-09-2017  15-09-2017     First Class
# Yonkers        1083  CA-2014-135755  01-03-2016  05-03-2016    Second Class
# York           2146  CA-2017-169404  09-04-2017  14-04-2017  Standard Class
# Yucaipa        3348  CA-2015-112014  13-08-2015  20-08-2015  Standard Class
# Yuma           4823  CA-2016-106621  10-07-2016  01-10-2016        Same Day
#
# ...

# %%
#How to concatenate_data in pandas

data1=sample_data.groupby('Category').count()
data1

data2=sample_data.groupby("Sub-Category").count()
data2
# Out:
#               Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# Sub-Category
# Accessories      775       775         775        775        775          775
# Appliances       466       466         466        466        466          466
# Art              796       796         796        796        796          796
# Binders         1523      1523        1523       1523       1523         1523
# Bookcases        228       228         228        228        228          228
# Chairs           617       617         617        617        617          617
# Copiers           68        68          68         68         68           68
# Envelopes        254       254         254        254        254          254
# Fasteners        217       217         217        217        217          217
# Furnishings      957       957         957        957        957          957
# Labels           364       364         364        364        364          364
# ...

# %%
data_concate=pd.concat([data1,data2])
data_concate
# Out:
#                  Row ID  Order ID  Order Date  Ship Date  Ship Mode  \
# Furniture          2121      2121        2121       2121       2121
# Office Supplies    6026      6026        6026       6026       6026
# Technology         1847      1847        1847       1847       1847
# Accessories         775       775         775        775        775
# Appliances          466       466         466        466        466
# Art                 796       796         796        796        796
# Binders            1523      1523        1523       1523       1523
# Bookcases           228       228         228        228        228
# Chairs              617       617         617        617        617
# Copiers              68        68          68         68         68
# Envelopes           254       254         254        254        254
# Fasteners           217       217         217        217        217
# Furnishings         957       957         957        957        957
# ...

# %%
#merge or join in pandas

sample_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sample_data.shape
# Out:
# (9994, 21)

# %%
sample_retrun_data=pd.read_csv("A:\LLM\Return_Superstore.csv")

# %%
sample_retrun_data.columns
# Out:
# Index(['Returned', 'Order ID'], dtype='object')

# %%
#let perform merge or join in pandas

data3=pd.merge(sample_data,sample_retrun_data, on='Order ID' )

# %%
data3.head()
data3.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Returned'],
#       dtype='object')

# %%
#let perform merge or join in pandas right join

data4=pd.merge(sample_data,sample_retrun_data, on='Order ID',how='right' )

# %%
data4
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0      6971  CA-2017-153822  19-09-2017  25-09-2017  Standard Class
# 1      6972  CA-2017-153822  19-09-2017  25-09-2017  Standard Class
# 2      6973  CA-2017-153822  19-09-2017  25-09-2017  Standard Class
# 3      6974  CA-2017-153822  19-09-2017  25-09-2017  Standard Class
# 4      5434  CA-2017-129707  25-04-2017  29-04-2017  Standard Class
# ..      ...             ...         ...         ...             ...
# 795     993  CA-2016-105585  26-08-2016  27-08-2016     First Class
# 796     994  CA-2016-105585  26-08-2016  27-08-2016     First Class
# 797     418  CA-2016-148796  14-04-2016  18-04-2016  Standard Class
# 798    7717  CA-2015-149636  06-01-2015  12-01-2015  Standard Class
# 799    7718  CA-2015-149636  06-01-2015  12-01-2015  Standard Class
#
#     Customer ID     Customer Name    Segment        Country              City  \
# ...

# %%
#let perform merge or join in pandas left join

data5=pd.merge(sample_data,sample_retrun_data, on='Order ID',how='left' )
data5.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data5.shape
# Out:
# (9994, 22)

# %%
#if you want to select particular coloumns in dataframes
#make sure of this comma
data5.iloc[:,[0,1,2]]
# Out:
#       Row ID        Order ID  Order Date
# 0          1  CA-2016-152156  08-11-2016
# 1          2  CA-2016-152156  08-11-2016
# 2          3  CA-2016-138688  12-06-2016
# 3          4  US-2015-108966  11-10-2015
# 4          5  US-2015-108966  11-10-2015
# ...      ...             ...         ...
# 9989    9990  CA-2014-110422  21-01-2014
# 9990    9991  CA-2017-121258  26-02-2017
# 9991    9992  CA-2017-121258  26-02-2017
# 9992    9993  CA-2017-121258  26-02-2017
# 9993    9994  CA-2017-119914  04-05-2017
#
# [9994 rows x 3 columns]

# %%
#if you want to apply data sort by order by after join or merge

data5=pd.merge(sample_data,sample_retrun_data, on='Order ID',how='left' )
data5.head()
data5.sort_values(by='Sales', ascending=False)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  18-03-2014  23-03-2014  Standard Class
# 6826    6827  CA-2016-118689  02-10-2016  09-10-2016  Standard Class
# 8153    8154  CA-2017-140151  23-03-2017  25-03-2017     First Class
# 2623    2624  CA-2017-127180  22-10-2017  24-10-2017     First Class
# 4190    4191  CA-2017-166709  17-11-2017  22-11-2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 2106    2107  US-2014-152723  26-09-2014  26-09-2014        Same Day
# 4711    4712  CA-2014-112403  31-03-2014  31-03-2014        Same Day
# 8658    8659  CA-2016-168361  21-06-2016  25-06-2016  Standard Class
# 9292    9293  CA-2017-124114  02-03-2017  02-03-2017        Same Day
# 4101    4102  US-2017-102288  19-06-2017  23-06-2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
#for example if we want to implement row_number here

sample_data_row_number=sample_data["Sales"].rank(method='first', ascending=False)

# %%
sample_data_row_number.shape
# Out:
# (9994,)

# %%
sample_data_row_number.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\GOURAV~1\AppData\Local\Temp/ipykernel_21332/3095762944.py in <module>
# ----> 1 sample_data_row_number.columns
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
sample_data["ranking"]=sample_data["Sales"].rank(method='first', ascending=False).astype(int)

# %%
sample_data.shape
# Out:
# (9994, 22)

# %%
sample_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'ranking'],
#       dtype='object')

# %%
sample_data['ranking']
# Out:
# 0       2121
# 1        719
# 2       7871
# 3        500
# 4       6920
#         ...
# 9989    6662
# 9990    3937
# 9991    2140
# 9992    6344
# 9993    2242
# Name: ranking, Length: 9994, dtype: int32

# %%
sample_data['ranking']==5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: ranking, Length: 9994, dtype: bool

# %%
sample_data[sample_data['ranking']==1]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  18-03-2014  23-03-2014  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
#
#      Region       Product ID    Category Sub-Category  \
# 2697  South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48        6
#
#       Discount     Profit  ranking
# 2697       0.5 -1811.0784        1
#
# [1 rows x 22 columns]

# %%
#for example if I need 1 and 2 ranking then we can use isin function

sample_data[sample_data['ranking'].isin([1,2])]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  18-03-2014  23-03-2014  Standard Class
# 6826    6827  CA-2016-118689  02-10-2016  09-10-2016  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
# 6826    TC-20980  Tamara Chand    Corporate  United States     Lafayette  ...
#
#        Region       Product ID    Category Sub-Category  \
# 2697    South  TEC-MA-10002412  Technology     Machines
# 6826  Central  TEC-CO-10004722  Technology      Copiers
#
#                                            Product Name     Sales Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48        6
# 6826              Canon imageCLASS 2200 Advanced Copier  17499.95        5
#
#       Discount     Profit  ranking
# 2697       0.5 -1811.0784        1
# 6826       0.0  8399.9760        2
#
# ...
